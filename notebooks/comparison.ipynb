# %%
import pandas as pd

# %%
gemma = pd.read_excel("english_hindi_backtranslation_results.xlsx")
marian = pd.read_excel("marian_bt.xlsx")
nllb = pd.read_excel("nllb_bt.xlsx")
mbart = pd.read_excel("mbart_bt.xlsx")

# %%
gemma = gemma.rename(columns={
    "orginal_sen": "en_original",
    "translate_hi": "hi_gemma",
    "back_translation_en": "back_gemma"
})


marian = marian.rename(columns={
    "hi_translation": "hi_marian",
    "en_backtranslation": "back_marian"
})


nllb = nllb.rename(columns={
    "hi_translation": "hi_nllb",
    "en_backtranslation": "back_nllb"
})

mbart = mbart.rename(columns={
    "hi_translation": "hi_mbart",
    "en_backtranslation": "back_mbart"
})

# %%
gemma = gemma.rename(columns={
    "original_sen": "en_original",   # FIXED
    "translate_hi": "hi_gemma",
    "back_translation_en": "back_gemma"
})

# %%
gemma = gemma[["sentence_id", "en_original", "hi_gemma", "back_gemma"]]
marian = marian[["sentence_id", "hi_marian", "back_marian"]]
nllb = nllb[["sentence_id", "hi_nllb", "back_nllb"]]
mbart = mbart[["sentence_id", "hi_mbart", "back_mbart"]]

# %%
comparison = gemma.merge(marian, on="sentence_id") \
                  .merge(nllb, on="sentence_id") \
                  .merge(mbart, on="sentence_id")

comparison.head()
# Out:
#    sentence_id                                       en_original  \
# 0            1                              Let's try something.
# 1            2                            I have to go to sleep.
# 2            3  Today is June 18th and it is Muiriel's birthday!
# 3            4                                Muiriel is 20 now.
# 4            5                        The password is "Muiriel".
#
#                                     hi_gemma  \
# 0               चलिए, हम कुछ कोशिश करते हैं।
# 1                         मुझे सोने जाना है।
# 2  आज 18 जून है और यह मियरीएल का जन्मदिन है!
# 3                    मुइरिल अब 20 साल की है।
# 4                     पासवर्ड "म्युरियल" है।
#
#                                           back_gemma  \
# 0                               Let's try something.
# 1                             I have to go to sleep.
# 2  Today is June 18th, and it's the birthday of M...
# 3                        Muiril is now 20 years old.
# 4                         The password is "Myurial".
#
#                                       hi_marian  \
# 0                       चलो कुछ कोशिश करते हैं.
# 1                        मुझे नींद में जाना है.
# 2  आज जून 18 वीं है और यह Marris का जन्मदिन है!
# 3                       मुंबरी अब 20 साल की है.
# 4                            पासवर्ड है "metel"
#
#                                      back_marian  \
# 0                           Let's try something.
# 1                         I have to go to sleep.
# 2  Today is June 18th and it's Marky's birthday!
# 3                    Muller is now 20 years old.
# 4                              Password is "mel"
#
#                                       hi_nllb  \
# 0                     चलो कुछ कोशिश करते हैं.
# 1                          मुझे सोने जाना है.
# 2  आज 18 जून है और यह म्यूरियल का जन्मदिन है!
# 3                     मुरियल अब 20 साल का है।
# 4                       पासवर्ड "Muiriel" है।
#
#                                         back_nllb  \
# 0                            Let's try something.
# 1                            I have to go to bed.
# 2  Today is June 18th and it's Muriel's birthday!
# 3                     Muriel is now 20 years old.
# 4                      The password is "Muiriel".
#
#                                  hi_mbart  \
# 0                     चलो कुछ कोशिश करें।
# 1                      मुझे सोने जाना है।
# 2  आज 18 जून है और मुइरीएल का जन्मदिन है!
# 3                मुइरीएल अब 20 साल का है।
# 4                   पासवर्ड "मुइरिएल" है।
#
#                                     back_mbart
# 0                        Let 's try something.
# 1                         I have to go to bed.
# 2  Today is June 18th and Mauriel 's birthday!
# 3                  Muriel is now 20 years old.
# 4                   The password is "Mauriel".

# %%
comparison.to_excel("comparison_all.xlsx", index=False)
print("Saved comparison_all.xlsx")
# Out:
# Saved comparison_all.xlsx

# %%
comparison[["sentence_id", "en_original", "back_gemma", "back_marian", "back_nllb","back_mbart"]].head(5)
# Out:
#    sentence_id                                       en_original  \
# 0            1                              Let's try something.
# 1            2                            I have to go to sleep.
# 2            3  Today is June 18th and it is Muiriel's birthday!
# 3            4                                Muiriel is 20 now.
# 4            5                        The password is "Muiriel".
#
#                                           back_gemma  \
# 0                               Let's try something.
# 1                             I have to go to sleep.
# 2  Today is June 18th, and it's the birthday of M...
# 3                        Muiril is now 20 years old.
# 4                         The password is "Myurial".
#
#                                      back_marian  \
# 0                           Let's try something.
# 1                         I have to go to sleep.
# 2  Today is June 18th and it's Marky's birthday!
# 3                    Muller is now 20 years old.
# 4                              Password is "mel"
#
#                                         back_nllb  \
# 0                            Let's try something.
# 1                            I have to go to bed.
# 2  Today is June 18th and it's Muriel's birthday!
# 3                     Muriel is now 20 years old.
# 4                      The password is "Muiriel".
#
#                                     back_mbart
# 0                        Let 's try something.
# 1                         I have to go to bed.
# 2  Today is June 18th and Mauriel 's birthday!
# 3                  Muriel is now 20 years old.
# 4                   The password is "Mauriel".

# %%
comparison[["sentence_id","hi_gemma", "hi_marian", "hi_nllb","hi_mbart"]].head(5)
# Out:
#    sentence_id                                   hi_gemma  \
# 0            1               चलिए, हम कुछ कोशिश करते हैं।
# 1            2                         मुझे सोने जाना है।
# 2            3  आज 18 जून है और यह मियरीएल का जन्मदिन है!
# 3            4                    मुइरिल अब 20 साल की है।
# 4            5                     पासवर्ड "म्युरियल" है।
#
#                                       hi_marian  \
# 0                       चलो कुछ कोशिश करते हैं.
# 1                        मुझे नींद में जाना है.
# 2  आज जून 18 वीं है और यह Marris का जन्मदिन है!
# 3                       मुंबरी अब 20 साल की है.
# 4                            पासवर्ड है "metel"
#
#                                       hi_nllb  \
# 0                     चलो कुछ कोशिश करते हैं.
# 1                          मुझे सोने जाना है.
# 2  आज 18 जून है और यह म्यूरियल का जन्मदिन है!
# 3                     मुरियल अब 20 साल का है।
# 4                       पासवर्ड "Muiriel" है।
#
#                                  hi_mbart
# 0                     चलो कुछ कोशिश करें।
# 1                      मुझे सोने जाना है।
# 2  आज 18 जून है और मुइरीएल का जन्मदिन है!
# 3                मुइरीएल अब 20 साल का है।
# 4                   पासवर्ड "मुइरिएल" है।

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (5.1.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: tqdm in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (2.9.0)
# Requirement already satisfied: scikit-learn in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: requests in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: colorama in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.9.18)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.8.3)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install sentence-transformers scikit-learn
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (5.1.2)
# Requirement already satisfied: scikit-learn in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (1.7.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: tqdm in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (2.9.0)
# Requirement already satisfied: scipy in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: filelock in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: requests in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: colorama in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.9.18)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manda\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.8.3)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
def compute_similarity(text1, text2):
    text1 = str(text1)
    text2 = str(text2)
    
    emb1 = model.encode(text1)
    emb2 = model.encode(text2)
    
    sim = cosine_similarity([emb1], [emb2])[0][0]
    return sim

# %%
comparison["sim_gemma"] = comparison.apply(
    lambda x: compute_similarity(x["en_original"], x["back_gemma"]), axis=1
)

comparison["sim_marian"] = comparison.apply(
    lambda x: compute_similarity(x["en_original"], x["back_marian"]), axis=1
)

comparison["sim_nllb"] = comparison.apply(
    lambda x: compute_similarity(x["en_original"], x["back_nllb"]), axis=1
)

comparison["sim_mbart"] = comparison.apply(
    lambda x: compute_similarity(x["en_original"], x["back_mbart"]), axis=1
)
comparison.head()
# Out:
#    sentence_id                                       en_original  \
# 0            1                              Let's try something.
# 1            2                            I have to go to sleep.
# 2            3  Today is June 18th and it is Muiriel's birthday!
# 3            4                                Muiriel is 20 now.
# 4            5                        The password is "Muiriel".
#
#                                     hi_gemma  \
# 0               चलिए, हम कुछ कोशिश करते हैं।
# 1                         मुझे सोने जाना है।
# 2  आज 18 जून है और यह मियरीएल का जन्मदिन है!
# 3                    मुइरिल अब 20 साल की है।
# 4                     पासवर्ड "म्युरियल" है।
#
#                                           back_gemma  \
# 0                               Let's try something.
# 1                             I have to go to sleep.
# 2  Today is June 18th, and it's the birthday of M...
# 3                        Muiril is now 20 years old.
# 4                         The password is "Myurial".
#
#                                       hi_marian  \
# 0                       चलो कुछ कोशिश करते हैं.
# 1                        मुझे नींद में जाना है.
# 2  आज जून 18 वीं है और यह Marris का जन्मदिन है!
# 3                       मुंबरी अब 20 साल की है.
# 4                            पासवर्ड है "metel"
#
#                                      back_marian  \
# 0                           Let's try something.
# 1                         I have to go to sleep.
# 2  Today is June 18th and it's Marky's birthday!
# 3                    Muller is now 20 years old.
# 4                              Password is "mel"
#
#                                       hi_nllb  \
# 0                     चलो कुछ कोशिश करते हैं.
# 1                          मुझे सोने जाना है.
# 2  आज 18 जून है और यह म्यूरियल का जन्मदिन है!
# 3                     मुरियल अब 20 साल का है।
# 4                       पासवर्ड "Muiriel" है।
#
#                                         back_nllb  \
# 0                            Let's try something.
# 1                            I have to go to bed.
# 2  Today is June 18th and it's Muriel's birthday!
# 3                     Muriel is now 20 years old.
# 4                      The password is "Muiriel".
#
#                                  hi_mbart  \
# 0                     चलो कुछ कोशिश करें।
# 1                      मुझे सोने जाना है।
# 2  आज 18 जून है और मुइरीएल का जन्मदिन है!
# 3                मुइरीएल अब 20 साल का है।
# 4                   पासवर्ड "मुइरिएल" है।
#
#                                     back_mbart  sim_gemma  sim_marian  \
# 0                        Let 's try something.   1.000000    1.000000
# 1                         I have to go to bed.   1.000000    1.000000
# 2  Today is June 18th and Mauriel 's birthday!   0.607721    0.663539
# 3                  Muriel is now 20 years old.   0.818054    0.588668
# 4                   The password is "Mauriel".   0.721748    0.639109
#
#    sim_nllb  sim_mbart
# 0  1.000000   1.000000
# 1  0.929535   0.929535
# 2  0.684408   0.677153
# 3  0.459096   0.459096
# 4  1.000000   0.758396

# %%
comparison[[
    "sentence_id",
    "en_original",
    "back_gemma", "sim_gemma",
    "back_marian", "sim_marian",
    "back_nllb", "sim_nllb",
    "back_mbart", "sim_mbart"
]].head(10)
# Out:
#    sentence_id                                       en_original  \
# 0            1                              Let's try something.
# 1            2                            I have to go to sleep.
# 2            3  Today is June 18th and it is Muiriel's birthday!
# 3            4                                Muiriel is 20 now.
# 4            5                        The password is "Muiriel".
# 5            6                              I will be back soon.
# 6            7                          I'm at a loss for words.
# 7            8                       This is never going to end.
# 8            9                    I just don't know what to say.
# 9           10                           That was an evil bunny.
#
#                                           back_gemma  sim_gemma  \
# 0                               Let's try something.   1.000000
# 1                             I have to go to sleep.   1.000000
# 2  Today is June 18th, and it's the birthday of M...   0.607721
# 3                        Muiril is now 20 years old.   0.818054
# 4                         The password is "Myurial".   0.721748
# 5                               I will be back soon.   1.000000
# 6                          I am at a loss for words.   0.955901
# 7                               This will never end.   0.897109
# 8                          I don't know what to say.   0.905477
# 9                            He was a wicked rabbit.   0.733828
#
#                                      back_marian  sim_marian  \
# 0                           Let's try something.    1.000000
# 1                         I have to go to sleep.    1.000000
# 2  Today is June 18th and it's Marky's birthday!    0.663539
# 3                    Muller is now 20 years old.    0.588668
# 4                              Password is "mel"    0.639109
# 5                             I'll be back soon.    0.964904
# 6                       I'm in a loss for words.    0.938854
# 7                       It's never going to end.    0.884280
# 8                 I don't know just what to say.    0.911993
# 9                             It was a bad shit.    0.326616
#
#                                         back_nllb  sim_nllb  \
# 0                            Let's try something.  1.000000
# 1                            I have to go to bed.  0.929535
# 2  Today is June 18th and it's Muriel's birthday!  0.684408
# 3                     Muriel is now 20 years old.  0.459096
# 4                      The password is "Muiriel".  1.000000
# 5                              I'll be back soon.  0.964904
# 6                            I'm losing my words.  0.769742
# 7                              It will never end.  0.824961
# 8                  I just don't know what to say.  1.000000
# 9                         It was a wicked rabbit.  0.759463
#
#                                     back_mbart  sim_mbart
# 0                        Let 's try something.   1.000000
# 1                         I have to go to bed.   0.929535
# 2  Today is June 18th and Mauriel 's birthday!   0.677153
# 3                  Muriel is now 20 years old.   0.459096
# 4                   The password is "Mauriel".   0.758396
# 5                          I 'll be back soon.   0.964904
# 6                           I 'm losing words.   0.796366
# 7                           It will never end.   0.824961
# 8              I just don 't know what to say.   1.000000
# 9                           It was a bad calf.   0.379622

# %%
print("Average Cosine Similarity Scores")
print("Gemma :", comparison["sim_gemma"].mean())
print("Marian:", comparison["sim_marian"].mean())
print("NLLB  :", comparison["sim_nllb"].mean())
print("mBART :", comparison["sim_mbart"].mean())
# Out:
# Average Cosine Similarity Scores
# Gemma : 0.8181878
# Marian: 0.8143202
# NLLB  : 0.8763379
# mBART : 0.8383664

# %%
threshold = 0.80

comparison["acc_gemma"] = comparison["sim_gemma"] >= threshold
comparison["acc_marian"] = comparison["sim_marian"] >= threshold
comparison["acc_nllb"] = comparison["sim_nllb"] >= threshold
comparison["acc_mbart"] = comparison["sim_mbart"] >= threshold

comparison.head()
# Out:
#    sentence_id                                       en_original  \
# 0            1                              Let's try something.
# 1            2                            I have to go to sleep.
# 2            3  Today is June 18th and it is Muiriel's birthday!
# 3            4                                Muiriel is 20 now.
# 4            5                        The password is "Muiriel".
#
#                                     hi_gemma  \
# 0               चलिए, हम कुछ कोशिश करते हैं।
# 1                         मुझे सोने जाना है।
# 2  आज 18 जून है और यह मियरीएल का जन्मदिन है!
# 3                    मुइरिल अब 20 साल की है।
# 4                     पासवर्ड "म्युरियल" है।
#
#                                           back_gemma  \
# 0                               Let's try something.
# 1                             I have to go to sleep.
# 2  Today is June 18th, and it's the birthday of M...
# 3                        Muiril is now 20 years old.
# 4                         The password is "Myurial".
#
#                                       hi_marian  \
# 0                       चलो कुछ कोशिश करते हैं.
# 1                        मुझे नींद में जाना है.
# 2  आज जून 18 वीं है और यह Marris का जन्मदिन है!
# 3                       मुंबरी अब 20 साल की है.
# 4                            पासवर्ड है "metel"
#
#                                      back_marian  \
# 0                           Let's try something.
# 1                         I have to go to sleep.
# 2  Today is June 18th and it's Marky's birthday!
# 3                    Muller is now 20 years old.
# 4                              Password is "mel"
#
#                                       hi_nllb  \
# 0                     चलो कुछ कोशिश करते हैं.
# 1                          मुझे सोने जाना है.
# 2  आज 18 जून है और यह म्यूरियल का जन्मदिन है!
# 3                     मुरियल अब 20 साल का है।
# 4                       पासवर्ड "Muiriel" है।
#
#                                         back_nllb  \
# 0                            Let's try something.
# 1                            I have to go to bed.
# 2  Today is June 18th and it's Muriel's birthday!
# 3                     Muriel is now 20 years old.
# 4                      The password is "Muiriel".
#
#                                  hi_mbart  \
# 0                     चलो कुछ कोशिश करें।
# 1                      मुझे सोने जाना है।
# 2  आज 18 जून है और मुइरीएल का जन्मदिन है!
# 3                मुइरीएल अब 20 साल का है।
# 4                   पासवर्ड "मुइरिएल" है।
#
#                                     back_mbart  sim_gemma  sim_marian  \
# 0                        Let 's try something.     1.0000      1.0000
# 1                         I have to go to bed.     1.0000      1.0000
# 2  Today is June 18th and Mauriel 's birthday!     0.6077      0.6635
# 3                  Muriel is now 20 years old.     0.8181      0.5887
# 4                   The password is "Mauriel".     0.7217      0.6391
#
#    sim_nllb  sim_mbart  acc_gemma  acc_marian  acc_nllb  acc_mbart
# 0    1.0000     1.0000       True        True      True       True
# 1    0.9295     0.9295       True        True      True       True
# 2    0.6844     0.6772      False       False     False      False
# 3    0.4591     0.4591       True       False     False      False
# 4    1.0000     0.7584      False       False      True      False

# %%
print("Accuracy based on cosine similarity threshold =", threshold)

print("Gemma Accuracy :", comparison["acc_gemma"].mean() * 100)
print("Marian Accuracy:", comparison["acc_marian"].mean() * 100)
print("NLLB Accuracy  :", comparison["acc_nllb"].mean() * 100)
print("mBART Accuracy :", comparison["acc_mbart"].mean() * 100)
# Out:
# Accuracy based on cosine similarity threshold = 0.8
# Gemma Accuracy : 62.0
# Marian Accuracy: 62.0
# NLLB Accuracy  : 76.5
# mBART Accuracy : 64.0

# %%
comparison["sim_gemma"] = comparison["sim_gemma"].round(4)
comparison["sim_marian"] = comparison["sim_marian"].round(4)
comparison["sim_nllb"] = comparison["sim_nllb"].round(4)
comparison["sim_mbart"] = comparison["sim_mbart"].round(4)

# %%
comparison.to_excel("final_comparison.xlsx", index=False)
print("File saved successfully")
# Out:
# File saved successfully

# %%
summary = pd.DataFrame({
    "Model": ["TranslateGemma", "MarianMT", "NLLB", "mBART"],
    
    "Average_Cosine_Similarity": [
        comparison["sim_gemma"].mean(),
        comparison["sim_marian"].mean(),
        comparison["sim_nllb"].mean(),
        comparison["sim_mbart"].mean()
    ],
    
    "Accuracy_Percentage": [
        comparison["acc_gemma"].mean() * 100,
        comparison["acc_marian"].mean() * 100,
        comparison["acc_nllb"].mean() * 100,
        comparison["acc_mbart"].mean() * 100
    ]
})

summary
# Out:
#             Model  Average_Cosine_Similarity  Accuracy_Percentage
# 0  TranslateGemma                   0.818184                 62.0
# 1        MarianMT                   0.814320                 62.0
# 2            NLLB                   0.876336                 76.5
# 3           mBART                   0.838365                 64.0

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.bar(summary["Model"], summary["Average_Cosine_Similarity"])

plt.title("Average Cosine Similarity by Model")
plt.xlabel("Model")
plt.ylabel("Cosine Similarity")

plt.show()

# %%
import matplotlib.pyplot as plt

summary = summary.reset_index(drop=True)

plt.figure()

plt.bar(summary["Model"], summary["Accuracy_Percentage"])

plt.title("Model Comparison - Accuracy")
plt.xlabel("Model")
plt.ylabel("Accuracy (%)")

plt.show()

# %%
low_cases = comparison.sort_values(by="sim_marian").head(5)

low_cases[[
    "en_original",
    "back_gemma", "sim_gemma",
    "back_marian", "sim_marian",
    "back_nllb", "sim_nllb",
    "back_mbart", "sim_mbart"
]]
# Out:
#                                 en_original  \
# 152                        Congratulations!
# 193     Nothing is beautiful but the truth.
# 196                          This is a pun.
# 73   I think it is best not to be impolite.
# 17                       I make €100 a day.
#
#                                  back_gemma  sim_gemma  \
# 152                        Congratulations!     1.0000
# 193                Only truth is beautiful.     0.8813
# 196                       This is a satire.     0.4866
# 73   I think it's best to avoid being rude.     0.6178
# 17              I earn 100 euros every day.     0.8614
#
#                                    back_marian  sim_marian  \
# 152                                   Killers!      0.1471
# 193            What is the Inevitable Reality?      0.1726
# 196                              It's a crazy.      0.2250
# 73   I think it's better not to be impossible.      0.2759
# 17                            I'll make a day.      0.2831
#
#                                    back_nllb  sim_nllb  \
# 152                         Congratulations!    1.0000
# 193      Nothing is beautiful but the truth.    1.0000
# 196                           It's a gamble.    0.3088
# 73   I think it is best not to be dishonest.    0.3545
# 17                   I earn 100 euros a day.    0.8735
#
#                                 back_mbart  sim_mbart
# 152                             Greetings!     0.4006
# 193    Nothing is beautiful but the truth.     1.0000
# 196                          It 's a joke.     0.4023
# 73   I think it 's best not to be awkward.     0.5143
# 17                 I earn 100 euros a day.     0.8735

# %%
subset = comparison.sort_values(by="sim_marian").head(5) 
subset = pd.concat([
    subset,
    comparison.sort_values(by="sim_marian", ascending=False).head(5)  
])

# %%
colors = ["green" if x >= 0.8 else "red" for x in subset["sim_marian"]]

plt.figure()

plt.bar(subset["en_original"], subset["sim_marian"], color=colors)

plt.axhline(y=0.8, color='black', linestyle='--', label='Threshold')

plt.xticks(rotation=45, ha="right")
plt.title("Translation Quality (Green = Accurate, Red = Poor)")
plt.ylabel("Cosine Similarity")

plt.show()
